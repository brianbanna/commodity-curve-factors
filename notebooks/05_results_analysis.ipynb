# %% [markdown]
# # Results Analysis
#
# **Goal:** Analyze backtest performance, risk metrics, and factor attribution.
#
# **Input:** Backtest results and performance data.
#
# **Output:** Performance reports, visualizations, and robustness analysis.
