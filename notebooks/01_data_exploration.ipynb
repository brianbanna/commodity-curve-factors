# %% [markdown]
# # Data Exploration
#
# **Goal:** Download, clean, and explore commodity futures data.
#
# **Input:** Raw futures data from Yahoo Finance/Quandl.
#
# **Output:** Cleaned continuous futures curves ready for feature extraction.
