# %% [markdown]
# # Strategy Backtest
#
# **Goal:** Build and backtest long-short factor-based trading strategies.
#
# **Input:** Factor signals and model outputs.
#
# **Output:** Backtest results with performance metrics and equity curves.
