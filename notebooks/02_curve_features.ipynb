# %% [markdown]
# # Curve Features
#
# **Goal:** Extract carry, slope, curvature, and roll yield features from futures curves.
#
# **Input:** Cleaned continuous futures curves.
#
# **Output:** Feature panel with daily factor values.
