# %% [markdown]
# # Factor Modeling
#
# **Goal:** Apply PCA, GARCH, and HMM to extract and model curve factors.
#
# **Input:** Feature panel with curve factors.
#
# **Output:** Factor models, volatility forecasts, and regime classifications.
